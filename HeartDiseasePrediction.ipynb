# %%
from google.colab import drive
drive.mount("/content/drive")
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv("drive/My Drive/DataSets/HeartDisease.csv")

# %%
data.head()
# Out:
#    male  age  education  currentSmoker  ...    BMI  heartRate  glucose  TenYearCHD
# 0     1   39        4.0              0  ...  26.97       80.0     77.0           0
# 1     0   46        2.0              0  ...  28.73       95.0     76.0           0
# 2     1   48        1.0              1  ...  25.34       75.0     70.0           0
# 3     0   61        3.0              1  ...  28.58       65.0    103.0           1
# 4     0   46        3.0              1  ...  23.10       85.0     85.0           0
#
# [5 rows x 16 columns]

# %%
data.tail()
# Out:
#       male  age  education  ...  heartRate  glucose  TenYearCHD
# 4233     1   50        1.0  ...       66.0     86.0           1
# 4234     1   51        3.0  ...       65.0     68.0           0
# 4235     0   48        2.0  ...       84.0     86.0           0
# 4236     0   44        1.0  ...       86.0      NaN           0
# 4237     0   52        2.0  ...       80.0    107.0           0
#
# [5 rows x 16 columns]

# %%
data.isnull().any()
# Out:
# male               False
# age                False
# education           True
# currentSmoker      False
# cigsPerDay          True
# BPMeds              True
# prevalentStroke    False
# prevalentHyp       False
# diabetes           False
# totChol             True
# sysBP              False
# diaBP              False
# BMI                 True
# heartRate           True
# glucose             True
# TenYearCHD         False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
data.describe()
# Out:
#               male          age  ...      glucose   TenYearCHD
# count  4238.000000  4238.000000  ...  3850.000000  4238.000000
# mean      0.429212    49.584946  ...    81.966753     0.151958
# std       0.495022     8.572160  ...    23.959998     0.359023
# min       0.000000    32.000000  ...    40.000000     0.000000
# 25%       0.000000    42.000000  ...    71.000000     0.000000
# 50%       0.000000    49.000000  ...    78.000000     0.000000
# 75%       1.000000    56.000000  ...    87.000000     0.000000
# max       1.000000    70.000000  ...   394.000000     1.000000
#
# [8 rows x 16 columns]

# %%
data.shape
# Out:
# (4238, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# memory usage: 529.9 KB

# %%
data['male'].unique()
# Out:
# array([1, 0])

# %%
data['age'].unique()
# Out:
# array([39, 46, 48, 61, 43, 63, 45, 52, 50, 41, 38, 42, 44, 47, 60, 35, 36,
#        59, 54, 37, 56, 53, 49, 65, 51, 62, 40, 67, 57, 66, 64, 55, 58, 34,
#        68, 33, 70, 32, 69])

# %%
data['education'].unique()
# Out:
# array([ 4.,  2.,  1.,  3., nan])

# %%
data['currentSmoker'].unique()
# Out:
# array([0, 1])

# %%
data['cigsPerDay'].unique()
# Out:
# array([ 0., 20., 30., 23., 15.,  9., 10.,  5., 35., 43.,  1., 40.,  3.,
#         2., nan, 12.,  4., 18., 25., 60., 14., 45.,  8., 50., 13., 11.,
#         7.,  6., 38., 29., 17., 16., 19., 70.])

# %%
data['BPMeds'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
data['prevalentStroke'].unique()
# Out:
# array([0, 1])

# %%
print(data['prevalentHyp'].unique())
# Out:
# [0 1]

# %%
data['diabetes'].unique()
# Out:
# array([0, 1])

# %%
data['totChol'].unique()
# Out:
# array([195., 250., 245., 225., 285., 228., 205., 313., 260., 254., 247.,
#        294., 332., 226., 221., 232., 291., 190., 185., 234., 215., 270.,
#        272., 295., 209., 175., 214., 257., 178., 233., 180., 243., 237.,
#         nan, 311., 208., 252., 261., 179., 194., 267., 216., 240., 266.,
#        255., 220., 235., 212., 223., 300., 302., 248., 200., 189., 258.,
#        202., 213., 183., 274., 170., 210., 197., 326., 188., 256., 244.,
#        193., 239., 296., 269., 275., 268., 265., 173., 273., 290., 278.,
#        264., 282., 241., 288., 222., 303., 246., 150., 187., 286., 154.,
#        279., 293., 259., 219., 230., 320., 312., 165., 159., 174., 242.,
#        301., 167., 308., 325., 229., 236., 224., 253., 464., 171., 186.,
#        227., 249., 176., 163., 191., 263., 196., 310., 164., 135., 238.,
#        207., 342., 287., 182., 352., 284., 217., 203., 262., 129., 155.,
#        323., 206., 283., 319., 304., 340., 328., 280., 368., 218., 276.,
#        339., 231., 198., 177., 201., 277., 184., 199., 168., 292., 305.,
#        306., 152., 161., 181., 251., 271., 370., 439., 145., 330., 157.,
#        398., 162., 314., 166., 160., 281., 289., 355., 307., 156., 329.,
#        143., 211., 298., 334., 192., 204., 318., 309., 353., 360., 335.,
#        158., 372., 346., 169., 140., 324., 600., 315., 392., 322., 149.,
#        137., 172., 317., 358., 153., 345., 391., 410., 297., 356., 338.,
#        107., 148., 366., 333., 327., 344., 126., 365., 362., 316., 144.,
#        351., 390., 321., 405., 359., 350., 336., 380., 299., 124., 371.,
#        113., 354., 382., 364., 341., 133., 367., 432., 337., 696., 363.,
#        331., 361., 453., 347., 373., 385., 119.])

# %%
data['sysBP'].unique()
# Out:
# array([106. , 121. , 127.5, 150. , 130. , 180. , 138. , 100. , 141.5,
#        162. , 133. , 131. , 142. , 124. , 114. , 140. , 112. , 122. ,
#        139. , 108. , 123.5, 148. , 132. , 137.5, 102. , 110. , 182. ,
#        115. , 134. , 147. , 124.5, 153.5, 160. , 153. , 111. , 116.5,
#        206. ,  96. , 179.5, 119. , 116. , 156.5, 145. , 143.5, 158. ,
#        157. , 126.5, 136. , 154. , 190. , 107. , 112.5, 164.5, 138.5,
#        155. , 151. , 152. , 179. , 113. , 200. , 132.5, 126. , 123. ,
#        141. , 135. , 187. , 127. , 160.5, 105. , 109. , 128. , 118. ,
#        109.5, 117.5, 149. , 180.5, 136.5, 212. , 125. , 191. , 121.5,
#        173. , 144. , 129.5, 117. , 144.5, 170. , 137. ,  94. , 119.5,
#        143. , 166. , 139.5, 177.5, 129. , 159. , 130.5, 107.5, 189. ,
#        168. , 197.5, 146. , 174. , 122.5,  98. , 131.5, 195. , 101. ,
#        158.5,  97. , 151.5,  97.5, 120. , 204. , 157.5, 140.5, 171. ,
#        215. ,  95. , 156. , 165. , 178. , 146.5, 113.5, 188. , 197. ,
#         90. , 152.5,  95.5, 209. , 162.5, 295. , 108.5, 103. , 145.5,
#        134.5, 115.5, 118.5, 174.5, 163. , 185. , 220. , 164. , 120.5,
#         98.5, 161. , 168.5, 176. , 163.5, 128.5, 167. , 205.5, 167.5,
#        172.5, 183. , 186. , 147.5, 175. , 142.5, 192. ,  96.5, 159.5,
#        177. , 102.5, 133.5, 244. , 104. , 213. , 199. , 184. , 198. ,
#        114.5, 125.5, 111.5, 105.5, 161.5, 171.5, 201. , 148.5, 169. ,
#        154.5,  93.5, 172. , 243. , 187.5,  99. , 181. , 100.5, 104.5,
#        135.5, 185.5, 103.5, 149.5, 182.5, 186.5, 217. , 196. , 193. ,
#        110.5, 155.5,  92. , 166.5, 202. , 150.5, 232. ,  85.5, 184.5,
#        235. , 205. , 169.5, 210. , 181.5, 188.5, 176.5,  92.5, 202.5,
#        191.5, 208. ,  83.5, 106.5, 170.5,  93. , 175.5, 207.5, 199.5,
#        101.5, 248. ,  99.5,  85. , 230. , 214. , 192.5, 194. , 207. ])

# %%
data['diaBP'].unique()
# Out:
# array([ 70. ,  81. ,  80. ,  95. ,  84. , 110. ,  71. ,  89. , 107. ,
#         76. ,  88. ,  94. ,  64. ,  90. ,  78. ,  84.5,  70.5,  77.5,
#         82. ,  68. ,  72.5,  91. , 121. ,  85.5,  85. ,  82.5,  74. ,
#         92.5, 102. ,  98. , 101. ,  73. ,  92. ,  83.5,  63. , 114. ,
#         69. ,  93. ,  66. ,  75. ,  79. ,  87. ,  99. ,  60. ,  67.5,
#        106. ,  86.5, 104. ,  86. ,  61.5,  71.5,  76.5,  77. ,  88.5,
#        105. ,  96. ,  97. , 100. ,  81.5, 106.5,  80.5, 124.5,  61. ,
#         83. ,  67. ,  74.5,  66.5,  65. ,  72. ,  99.5, 122.5,  57. ,
#         57.5, 111. ,  78.5, 104.5,  89.5, 112. ,  55. , 123. , 120. ,
#         75.5, 118. ,  97.5,  59. , 133. ,  69.5,  95.5,  96.5, 135. ,
#         64.5,  68.5,  98.5,  62. , 117. ,  59.5, 103. , 108.5,  73.5,
#         87.5, 108. ,  93.5,  90.5, 114.5,  62.5,  94.5, 140. , 124. ,
#         79.5, 109. ,  91.5, 115. , 102.5,  65.5, 105.5, 103.5,  63.5,
#        107.5, 142.5, 109.5,  58. , 117.5, 116.5, 100.5, 116. , 119. ,
#         54. , 132. ,  50. , 101.5, 136. ,  51. , 128. , 125. , 112.5,
#        130. , 110.5, 113. ,  53. , 129. ,  52. ,  48. ,  56. ,  60.5,
#        115.5, 127.5])

# %%
data['BMI'].unique()
# Out:
# array([26.97, 28.73, 25.34, ..., 39.17, 26.7 , 43.67])

# %%
data['heartRate'].unique()
# Out:
# array([ 80.,  95.,  75.,  65.,  85.,  77.,  60.,  79.,  76.,  93.,  72.,
#         98.,  64.,  70.,  71.,  62.,  73.,  90.,  96.,  68.,  63.,  88.,
#         78.,  83., 100.,  67.,  84.,  57.,  50.,  74.,  86.,  55.,  92.,
#         66.,  87., 110.,  81.,  56.,  89.,  82.,  48., 105.,  61.,  54.,
#         69.,  52.,  94., 140., 130.,  58., 108., 104.,  91.,  53.,  nan,
#        106.,  59.,  51., 102., 107., 112., 125., 103.,  44.,  47.,  45.,
#         97., 122., 120.,  99., 115., 143., 101.,  46.])

# %%
data['glucose'].unique()
# Out:
# array([ 77.,  76.,  70., 103.,  85.,  99.,  78.,  79.,  88.,  61.,  64.,
#         84.,  nan,  72.,  89.,  65., 113.,  75.,  83.,  66.,  74.,  63.,
#         87., 225.,  90.,  80., 100., 215.,  98.,  62.,  95.,  94.,  55.,
#         82.,  93.,  73.,  45., 202.,  68.,  97., 104.,  96., 126., 120.,
#        105.,  71.,  56.,  60., 117., 102.,  58.,  92., 109.,  86., 107.,
#         54.,  67.,  69.,  57.,  91., 132., 150.,  59.,  81., 115., 140.,
#        112., 118., 143., 114., 160., 110., 123., 108., 145., 122., 137.,
#        106., 127., 205., 130., 101.,  47.,  53., 216., 163., 144., 116.,
#        121., 172., 124., 111.,  40., 186., 223., 325.,  44., 156., 268.,
#         50., 274., 292., 255., 136., 206., 131., 148., 297.,  43., 173.,
#         48., 386., 155., 147., 170.,  52., 320., 254., 394., 270., 244.,
#        183., 142., 119., 135., 167., 207., 129., 177., 250., 294., 166.,
#        125., 332., 368., 348., 248., 370., 193., 191., 256., 235., 210.,
#        260.])

# %% [markdown]
# Categorical variables : Male, Education, CurrrentSmoker, BPMeds, prevalentStroke, prevelantHyp, Diabetes, tenYearCHD
#
# Numerical/Continuous variables : Age, cigsPerDay, totChol, sysBP, diaBP, BMI, heartRate, glucose

# %%
import seaborn as sns

# %%
data.isnull().any()
# Out:
# male               False
# age                False
# education           True
# currentSmoker      False
# cigsPerDay          True
# BPMeds              True
# prevalentStroke    False
# prevalentHyp       False
# diabetes           False
# totChol             True
# sysBP              False
# diaBP              False
# BMI                 True
# heartRate           True
# glucose             True
# TenYearCHD         False
# dtype: bool

# %% [markdown]
# **Variables with missing values:**
#
# Categorical : Education, BPMeds
#
# Continuous : cigsPerDay, totChol, BMI, glucose, heartRate

# %%
sns.boxplot(data['cigsPerDay'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#cigsPerDay has outliers -Replacing missing values with median
data['cigsPerDay'].fillna(0, inplace=True)
data.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay           0
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
sns.boxplot(data['totChol'],orient="v")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
data['totChol'].fillna(data['totChol'].median(), inplace=True)
data.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay           0
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol              0
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
sns.boxplot(data['BMI'],orient="v")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
data['BMI'].fillna(data['BMI'].median(), inplace=True)
data.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay           0
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol              0
# sysBP                0
# diaBP                0
# BMI                  0
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
sns.boxplot(data['glucose'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import matplotlib.pyplot as plt
plt.hist(data['glucose'],bins=10)
# Out:
# (array([1572., 2097.,  127.,   16.,   13.,    6.,    7.,    4.,    3.,
#            5.]),
#  array([ 40. ,  75.4, 110.8, 146.2, 181.6, 217. , 252.4, 287.8, 323.2,
#         358.6, 394. ]),
#  <a list of 10 Patch objects>)

# %%
data['glucose'].fillna(data['glucose'].median(), inplace=True)
data.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay           0
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol              0
# sysBP                0
# diaBP                0
# BMI                  0
# heartRate            1
# glucose              0
# TenYearCHD           0
# dtype: int64

# %%
sns.countplot(data['education'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data['education']=data['education'].fillna(0)

# %%
sns.countplot(data['education'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data['BPMeds'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data['BPMeds']=data['BPMeds'].fillna(2)
data.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          1
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
import seaborn as sns
cor=data.corr()
plt.figure(figsize=(12,12))
ax=sns.heatmap(cor,annot=True)

# %%
data_numerical=data.drop(['male','education','currentSmoker','BPMeds','prevalentStroke','prevalentHyp','diabetes','TenYearCHD'],axis=1)

# %%
data_numerical.head()
# Out:
#    age  cigsPerDay  totChol  sysBP  diaBP    BMI  heartRate  glucose
# 0   39         0.0    195.0  106.0   70.0  26.97       80.0     77.0
# 1   46         0.0    250.0  121.0   81.0  28.73       95.0     76.0
# 2   48        20.0    245.0  127.5   80.0  25.34       75.0     70.0
# 3   61        30.0    225.0  150.0   95.0  28.58       65.0    103.0
# 4   46        23.0    285.0  130.0   84.0  23.10       85.0     85.0

# %%
data_categorical=data.drop(['age','cigsPerDay','totChol','sysBP','diaBP','BMI','heartRate','glucose','TenYearCHD'],axis=1)

# %%
data_categorical.head()
# Out:
#    male  education  currentSmoker  ...  prevalentStroke  prevalentHyp  diabetes
# 0     1        4.0              0  ...                0             0         0
# 1     0        2.0              0  ...                0             0         0
# 2     1        1.0              1  ...                0             0         0
# 3     0        3.0              1  ...                0             1         0
# 4     0        3.0              1  ...                0             0         0
#
# [5 rows x 7 columns]

# %%
#Categorical variables Vs. Target - Bar Plot
import matplotlib.pyplot as plt
for col in data_categorical.columns:
  plt.figure()
  sns.barplot(x=col,y="TenYearCHD",data=data)
plt.show()

# %%
import matplotlib.pyplot as plt
for col in data_categorical.columns:
  plt.figure()
  sns.barplot(x=col,y="TenYearCHD",data=data,hue='prevalentHyp')
plt.show()

# %%
import matplotlib.pyplot as plt
for col in data_categorical.columns:
  plt.figure()
  sns.barplot(x=col,y="TenYearCHD",data=data,hue='male')
plt.show()

# %%
axis=sns.boxplot(x="TenYearCHD",y="cigsPerDay",data=data)

# %%
axis=sns.boxplot(x="TenYearCHD",y="sysBP",data=data)

# %%
import matplotlib.pyplot as plt
for col in data_numerical.columns:
  plt.figure()
  sns.boxplot(x="TenYearCHD",y=col,data=data)
plt.show()

# %%
import matplotlib.pyplot as plt
for col in data_numerical.columns:
  plt.figure()
  sns.boxplot(x="TenYearCHD",y=col,data=data,hue="prevalentHyp")
plt.show()

# %%
sns.boxplot(x=data['BPMeds'],y=data['age'])

# %%
sns.countplot(x="TenYearCHD",data=data)

# %% [markdown]
# It is an unbalanced dataset->Performance metric=f1score
#
# Classification algorithms:
# Logistic Regression,
# Decision Tree,
# SVM,
# Random Forest,
# Ensemble methods- Gradient Boosting Classifier, Stacking Classifier
# Light Gradient Boosted Machine
# Extreme gradient boost

# %%
y=data['TenYearCHD']
x=data.drop(['TenYearCHD'],axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state = 42)

# %%
x_train.shape
# Out:
# (3389, 15)

# %%
x_test.shape
# Out:
# (848, 15)

# %%
import sklearn
sorted(sklearn.metrics.SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'max_error',
#  'mutual_info_score',
#  'neg_brier_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_absolute_percentage_error',
#  'neg_mean_gamma_deviance',
#  'neg_mean_poisson_deviance',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'neg_root_mean_squared_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'rand_score',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'roc_auc_ovo',
#  'roc_auc_ovo_weighted',
#  'roc_auc_ovr',
#  'roc_auc_ovr_weighted',
#  'top_k_accuracy',
#  'v_measure_score']

# %%
models = []
f1Scores = []

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
scores=cross_val_score(logreg,x,y,cv=10,scoring="f1_micro")

# %%
print(scores)
# Out:
# [0.84433962 0.86320755 0.85377358 0.86084906 0.8490566  0.8490566
#  0.86792453 0.85815603 0.85579196 0.84869976]

# %%
scores.mean()
# Out:
# 0.8550855301306927

# %%
models.append("Logitic Regression")
f1Scores.append(scores.mean())

# %%
models, f1Scores
# Out:
# (['Logitic Regression'], [0.8550855301306927])

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predicted=lr.predict(x_test)

# %%
score_lr = lr.score(x_test, y_test)
print(score_lr)
# Out:
# 0.8466981132075472

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.92       714
#            1       0.67      0.06      0.11       134
#
#     accuracy                           0.85       848
#    macro avg       0.76      0.53      0.51       848
# weighted avg       0.82      0.85      0.79       848

# %%
from sklearn.metrics import f1_score

# %%
print(f1_score(y_test,y_predicted,average='micro'))
# Out:
# 0.8466981132075472

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree=DecisionTreeClassifier()
scores_decisionTree=cross_val_score(decision_tree,x,y,cv=10,scoring="f1_micro")

# %%
scores_decisionTree
# Out:
# array([0.74056604, 0.76886792, 0.74528302, 0.75943396, 0.74292453,
#        0.74528302, 0.73584906, 0.76595745, 0.73286052, 0.73049645])

# %%
scores_decisionTree.mean()
# Out:
# 0.7467521967973594

# %%
models.append("Decision Tree")
f1Scores.append(scores_decisionTree.mean())

# %%
decision_tree2=DecisionTreeClassifier(criterion="entropy",min_samples_split=10,splitter="random")
scores_decisionTree2=cross_val_score(decision_tree2,x,y,cv=10,scoring="f1_micro")

# %%
scores_decisionTree2
# Out:
# array([0.79245283, 0.81367925, 0.75235849, 0.80896226, 0.78537736,
#        0.79716981, 0.81839623, 0.81323877, 0.79905437, 0.80378251])

# %%
scores_decisionTree2.mean()
# Out:
# 0.7984471876533299

# %%
models.append("Decision Tree 2")
f1Scores.append(scores_decisionTree2.mean())

# %%
from sklearn.svm import SVC
svm1=SVC(kernel="poly",degree=5,gamma="auto")
scores_svm1=cross_val_score(svm1,x,y,cv=10,scoring="f1_micro")

# %%
scores_svm1
# Out:
# array([0.83254717, 0.84669811, 0.83726415, 0.86084906, 0.8254717 ,
#        0.84198113, 0.86556604, 0.8534279 , 0.8392435 , 0.82742317])

# %%
scores_svm1.mean()
# Out:
# 0.8430471921138321

# %%
models.append("SVM 1")
f1Scores.append(scores_svm1.mean())

# %%
svm2=SVC(kernel="rbf")
scores_svm2=cross_val_score(svm2,x,y,cv=10,scoring="f1_micro")
print(scores_svm2)
print(scores_svm2.mean())
# Out:
# [0.8490566  0.84669811 0.84669811 0.85377358 0.84669811 0.84433962
#  0.84433962 0.85106383 0.84869976 0.84869976]
# 0.84800671305589

# %%
models.append("SVM 2")
f1Scores.append(scores_svm2.mean())

# %%
from sklearn.ensemble import RandomForestClassifier
randomforest=RandomForestClassifier(max_depth=10)
scores_randomforest=cross_val_score(randomforest,x,y,cv=10,scoring="f1_micro")
print(scores_randomforest)
print(scores_randomforest.mean())
# Out:
# [0.84433962 0.84669811 0.85141509 0.85377358 0.84433962 0.84198113
#  0.85377358 0.85579196 0.84869976 0.85106383]
# 0.8491876310272536

# %%
models.append("Random Forest")
f1Scores.append(scores_randomforest.mean())

# %%
from sklearn.ensemble import GradientBoostingClassifier
gradBoost=GradientBoostingClassifier(loss="exponential",learning_rate=0.001, n_estimators=50, max_depth=10)
scores_gradBoost=cross_val_score(gradBoost,x,y,cv=10,scoring="f1_micro")
print(scores_gradBoost)
print(scores_gradBoost.mean())
# Out:
# [0.8490566  0.8490566  0.8490566  0.8490566  0.84669811 0.84669811
#  0.84669811 0.84869976 0.84869976 0.84869976]
# 0.8482420045497123

# %%
models.append("Gradient Boosting Classifier")
f1Scores.append(scores_gradBoost.mean())

# %%
from xgboost import XGBClassifier
xgBoost= XGBClassifier(learning_rate=0.01, n_estimators=25, max_depth=15,gamma=0.6, subsample=0.52,colsample_bytree=0.6,seed=27, 
                    reg_lambda=2, booster='dart', colsample_bylevel=0.6, colsample_bynode=0.5)
scores_xgBoost=cross_val_score(xgBoost,x,y,cv=10,scoring="f1_micro")
print(scores_xgBoost)
print(scores_xgBoost.mean())
# Out:
# [0.8490566  0.8490566  0.8490566  0.8490566  0.84669811 0.84669811
#  0.84669811 0.84869976 0.84869976 0.84869976]
# 0.8482420045497123

# %%
models.append("XG Boost Classifier")
f1Scores.append(scores_xgBoost.mean())

# %%
from sklearn.ensemble import StackingClassifier
estimators=[('xgBoost',XGBClassifier(learning_rate=0.01, n_estimators=25, max_depth=15,gamma=0.6, subsample=0.52,colsample_bytree=0.6,seed=27, 
                    reg_lambda=2, booster='dart', colsample_bylevel=0.6, colsample_bynode=0.5)),
            ('randomforest',RandomForestClassifier(max_depth=10)),
            ('svm',SVC(kernel="rbf"))]
stackClassifier=StackingClassifier(estimators=estimators,cv=10,final_estimator=LogisticRegression())
stackClassifier.fit(x_train,y_train)
# Out:
# StackingClassifier(cv=10,
#                    estimators=[('xgBoost',
#                                 XGBClassifier(booster='dart',
#                                               colsample_bylevel=0.6,
#                                               colsample_bynode=0.5,
#                                               colsample_bytree=0.6, gamma=0.6,
#                                               learning_rate=0.01, max_depth=15,
#                                               n_estimators=25, reg_lambda=2,
#                                               seed=27, subsample=0.52)),
#                                ('randomforest',
#                                 RandomForestClassifier(max_depth=10)),
#                                ('svm', SVC())],
#                    final_estimator=LogisticRegression())

# %%
stackClassifier.score(x_test,y_test)
# Out:
# 0.8419811320754716

# %%
y_predicted_stackClass=stackClassifier.predict(x_test)

# %%
print("F1-score of Stacking classifier",f1_score(y_test,y_predicted,average="micro"))
# Out:
# F1-score of Stacking classifier 0.8466981132075472

# %%
models.append("Stacking Classifier")
f1Scores.append(0.8466981132075472)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gradBoost=GradientBoostingClassifier(loss="exponential",learning_rate=0.01, n_estimators=50, max_depth=10,random_state=42)
gradBoost.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, loss='exponential', max_depth=10,
#                            n_estimators=50, random_state=42)

# %%
ypredGradBoost=gradBoost.predict(x_test)

# %%
print("F1-score of Gradient Boosting classifier",f1_score(y_test,ypredGradBoost,average="micro"))
# Out:
# F1-score of Gradient Boosting classifier 0.8419811320754716

# %%
gradBoost.score(x_test,y_test)
# Out:
# 0.8419811320754716

# %%
print(classification_report(y_test,ypredGradBoost))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       714
#            1       0.00      0.00      0.00       134
#
#     accuracy                           0.84       848
#    macro avg       0.42      0.50      0.46       848
# weighted avg       0.71      0.84      0.77       848
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(gradBoost.feature_importances_)
# Out:
# [0.02711182 0.14905068 0.03192639 0.00337747 0.05774261 0.00758095
#  0.00258885 0.01085337 0.00577761 0.13148648 0.13725023 0.10200531
#  0.13083541 0.07916776 0.12324506]

# %%
gradBoost_importance=list(gradBoost.feature_importances_)
allfeatures=data.drop('TenYearCHD',axis=1)
features=list(allfeatures.columns)
fig = plt.figure(figsize = (15, 5)) 
plt.barh(features, gradBoost_importance, color ='blue') 
plt.title('Gradient Boosting Classifier model-Feature importances')
plt.xlabel("Features/Factors causing heart disease") 
plt.ylabel("Feature importance") 
plt.show()

# %% [markdown]
# Hyper Parameter Tuning using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid1={'n_estimators':range(20,81,10)}
gridSearch1=GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, min_samples_split=500,min_samples_leaf=50,max_depth=8,max_features='sqrt',subsample=0.8,random_state=42), 
param_grid = param_grid1, scoring='f1_micro', cv=5)
gridSearch1.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=GradientBoostingClassifier(max_depth=8,
#                                                   max_features='sqrt',
#                                                   min_samples_leaf=50,
#                                                   min_samples_split=500,
#                                                   random_state=42,
#                                                   subsample=0.8),
#              param_grid={'n_estimators': range(20, 81, 10)},
#              scoring='f1_micro')

# %%
results=gridSearch1.cv_results_
print("           Params       MeanTestScore    StdTestScore   Rank")
for i in range(len(results['params'])):
  print(results['params'][i],'    ',round(results['mean_test_score'][i],4),'    ',round(results['std_test_score'][i],4),'     ',results['rank_test_score'][i])
# Out:
#            Params       MeanTestScore    StdTestScore   Rank
# {'n_estimators': 20}      0.8498      0.0005       7
# {'n_estimators': 30}      0.851      0.0009       5
# {'n_estimators': 40}      0.8516      0.0014       4
# {'n_estimators': 50}      0.8507      0.0025       6
# {'n_estimators': 60}      0.8522      0.0033       1
# {'n_estimators': 70}      0.8516      0.005       3
# {'n_estimators': 80}      0.8516      0.0064       2

# %%
gridSearch1.best_params_, gridSearch1.best_score_
# Out:
# ({'n_estimators': 60}, 0.8521705598619626)

# %%
param_grid2 = {'max_depth':range(5,16,2), 'min_samples_split':range(20,201,20)}
gridSearch2=GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, n_estimators=60, max_features='sqrt', subsample=0.8,random_state=42), 
param_grid = param_grid2, scoring='f1_micro', cv=5)
gridSearch2.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=GradientBoostingClassifier(max_features='sqrt',
#                                                   n_estimators=60,
#                                                   random_state=42,
#                                                   subsample=0.8),
#              param_grid={'max_depth': range(5, 16, 2),
#                          'min_samples_split': range(20, 201, 20)},
#              scoring='f1_micro')

# %%
results=gridSearch2.cv_results_
print("             Params                      MeanTestScore    StdTestScore   Rank")
for i in range(len(results['params'])):
  print(results['params'][i],'    ',round(results['mean_test_score'][i],4),'    ',round(results['std_test_score'][i],4),'     ',results['rank_test_score'][i])
# Out:
#              Params                      MeanTestScore    StdTestScore   Rank
# {'max_depth': 5, 'min_samples_split': 20}      0.8486      0.0056       6
# {'max_depth': 5, 'min_samples_split': 40}      0.8498      0.0072       3
# {'max_depth': 5, 'min_samples_split': 60}      0.8498      0.009       2
# {'max_depth': 5, 'min_samples_split': 80}      0.8489      0.0051       5
# {'max_depth': 5, 'min_samples_split': 100}      0.8463      0.0079       16
# {'max_depth': 5, 'min_samples_split': 120}      0.8477      0.007       9
# {'max_depth': 5, 'min_samples_split': 140}      0.8457      0.0059       18
# {'max_depth': 5, 'min_samples_split': 160}      0.848      0.0058       8
# {'max_depth': 5, 'min_samples_split': 180}      0.8475      0.007       10
# {'max_depth': 5, 'min_samples_split': 200}      0.8513      0.0081       1
# {'max_depth': 7, 'min_samples_split': 20}      0.8421      0.0089       43
# {'max_depth': 7, 'min_samples_split': 40}      0.8451      0.0089       22
# {'max_depth': 7, 'min_samples_split': 60}      0.8413      0.0049       47
# {'max_depth': 7, 'min_samples_split': 80}      0.8451      0.0066       20
# {'max_depth': 7, 'min_samples_split': 100}      0.8486      0.0048       7
# {'max_depth': 7, 'min_samples_split': 120}      0.8445      0.0077       26
# {'max_depth': 7, 'min_samples_split': 140}      0.8457      0.0057       18
# {'max_depth': 7, 'min_samples_split': 160}      0.8448      0.0044       24
# {'max_depth': 7, 'min_samples_split': 180}      0.8472      0.0063       12
# {'max_depth': 7, 'min_samples_split': 200}      0.8472      0.0066       11
# {'max_depth': 9, 'min_samples_split': 20}      0.8436      0.0073       32
# {'max_depth': 9, 'min_samples_split': 40}      0.8395      0.0092       56
# {'max_depth': 9, 'min_samples_split': 60}      0.8416      0.0078       45
# {'max_depth': 9, 'min_samples_split': 80}      0.8427      0.0054       40
# {'max_depth': 9, 'min_samples_split': 100}      0.8451      0.0052       21
# {'max_depth': 9, 'min_samples_split': 120}      0.8445      0.0051       27
# {'max_depth': 9, 'min_samples_split': 140}      0.8451      0.0033       23
# {'max_depth': 9, 'min_samples_split': 160}      0.8436      0.0076       31
# {'max_depth': 9, 'min_samples_split': 180}      0.8492      0.0073       4
# {'max_depth': 9, 'min_samples_split': 200}      0.8466      0.0043       15
# {'max_depth': 11, 'min_samples_split': 20}      0.8386      0.0044       58
# {'max_depth': 11, 'min_samples_split': 40}      0.8418      0.0056       44
# {'max_depth': 11, 'min_samples_split': 60}      0.8404      0.0077       52
# {'max_depth': 11, 'min_samples_split': 80}      0.8398      0.0057       55
# {'max_depth': 11, 'min_samples_split': 100}      0.841      0.0073       49
# {'max_depth': 11, 'min_samples_split': 120}      0.8463      0.0064       17
# {'max_depth': 11, 'min_samples_split': 140}      0.8433      0.0043       35
# {'max_depth': 11, 'min_samples_split': 160}      0.8466      0.0076       14
# {'max_depth': 11, 'min_samples_split': 180}      0.8472      0.0039       13
# {'max_depth': 11, 'min_samples_split': 200}      0.8433      0.0038       34
# {'max_depth': 13, 'min_samples_split': 20}      0.838      0.0057       59
# {'max_depth': 13, 'min_samples_split': 40}      0.841      0.0058       50
# {'max_depth': 13, 'min_samples_split': 60}      0.8398      0.0097       53
# {'max_depth': 13, 'min_samples_split': 80}      0.8448      0.0058       25
# {'max_depth': 13, 'min_samples_split': 100}      0.8424      0.0058       42
# {'max_depth': 13, 'min_samples_split': 120}      0.8436      0.0107       30
# {'max_depth': 13, 'min_samples_split': 140}      0.841      0.0054       51
# {'max_depth': 13, 'min_samples_split': 160}      0.8415      0.0062       46
# {'max_depth': 13, 'min_samples_split': 180}      0.843      0.005       37
# {'max_depth': 13, 'min_samples_split': 200}      0.8442      0.0066       29
# {'max_depth': 15, 'min_samples_split': 20}      0.8436      0.0067       33
# {'max_depth': 15, 'min_samples_split': 40}      0.8398      0.0079       54
# {'max_depth': 15, 'min_samples_split': 60}      0.8427      0.0052       41
# {'max_depth': 15, 'min_samples_split': 80}      0.8377      0.0062       60
# {'max_depth': 15, 'min_samples_split': 100}      0.8395      0.0083       57
# {'max_depth': 15, 'min_samples_split': 120}      0.843      0.009       36
# {'max_depth': 15, 'min_samples_split': 140}      0.841      0.0076       48
# {'max_depth': 15, 'min_samples_split': 160}      0.8427      0.0066       38
# {'max_depth': 15, 'min_samples_split': 180}      0.8442      0.0053       28
# {'max_depth': 15, 'min_samples_split': 200}      0.8427      0.0075       38

# %%
gridSearch2.best_params_, gridSearch2.best_score_
# Out:
# ({'max_depth': 5, 'min_samples_split': 200}, 0.8512873470063573)

# %% [markdown]
# Parameters fixed till now:
#
# n_estimators-50, max_depth-5

# %%
param_grid3 = {'min_samples_leaf':range(10,81,10),'min_samples_split':range(200,301,20)}
gridSearch3=GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, n_estimators=50,max_depth=5,max_features='sqrt', subsample=0.8, random_state=42), 
param_grid = param_grid3, scoring='f1_micro', cv=5)
gridSearch3.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=GradientBoostingClassifier(max_depth=5,
#                                                   max_features='sqrt',
#                                                   n_estimators=50,
#                                                   random_state=42,
#                                                   subsample=0.8),
#              param_grid={'min_samples_leaf': range(10, 81, 10),
#                          'min_samples_split': range(200, 301, 20)},
#              scoring='f1_micro')

# %%
results=gridSearch3.cv_results_
print("           Params       MeanTestScore    StdTestScore   Rank")
for i in range(len(results['params'])):
  print(results['params'][i],'    ',round(results['mean_test_score'][i],4),'    ',round(results['std_test_score'][i],4),'     ',results['rank_test_score'][i])
# Out:
#            Params       MeanTestScore    StdTestScore   Rank
# {'min_samples_leaf': 10, 'min_samples_split': 200}      0.8492      0.007       41
# {'min_samples_leaf': 10, 'min_samples_split': 220}      0.8519      0.007       6
# {'min_samples_leaf': 10, 'min_samples_split': 240}      0.851      0.0055       18
# {'min_samples_leaf': 10, 'min_samples_split': 260}      0.8522      0.0071       4
# {'min_samples_leaf': 10, 'min_samples_split': 280}      0.8489      0.0056       45
# {'min_samples_leaf': 10, 'min_samples_split': 300}      0.8495      0.0058       34
# {'min_samples_leaf': 20, 'min_samples_split': 200}      0.8504      0.0062       27
# {'min_samples_leaf': 20, 'min_samples_split': 220}      0.8486      0.0076       46
# {'min_samples_leaf': 20, 'min_samples_split': 240}      0.8495      0.0055       34
# {'min_samples_leaf': 20, 'min_samples_split': 260}      0.8489      0.0068       43
# {'min_samples_leaf': 20, 'min_samples_split': 280}      0.8489      0.0065       43
# {'min_samples_leaf': 20, 'min_samples_split': 300}      0.846      0.0042       48
# {'min_samples_leaf': 30, 'min_samples_split': 200}      0.8513      0.0047       13
# {'min_samples_leaf': 30, 'min_samples_split': 220}      0.851      0.0051       18
# {'min_samples_leaf': 30, 'min_samples_split': 240}      0.8507      0.0052       23
# {'min_samples_leaf': 30, 'min_samples_split': 260}      0.8495      0.0043       39
# {'min_samples_leaf': 30, 'min_samples_split': 280}      0.8472      0.0038       47
# {'min_samples_leaf': 30, 'min_samples_split': 300}      0.8507      0.004       24
# {'min_samples_leaf': 40, 'min_samples_split': 200}      0.8492      0.0043       42
# {'min_samples_leaf': 40, 'min_samples_split': 220}      0.8519      0.0053       7
# {'min_samples_leaf': 40, 'min_samples_split': 240}      0.8501      0.008       29
# {'min_samples_leaf': 40, 'min_samples_split': 260}      0.8495      0.005       37
# {'min_samples_leaf': 40, 'min_samples_split': 280}      0.8498      0.0045       33
# {'min_samples_leaf': 40, 'min_samples_split': 300}      0.8519      0.0062       9
# {'min_samples_leaf': 50, 'min_samples_split': 200}      0.851      0.0052       17
# {'min_samples_leaf': 50, 'min_samples_split': 220}      0.8504      0.0046       28
# {'min_samples_leaf': 50, 'min_samples_split': 240}      0.8501      0.0055       31
# {'min_samples_leaf': 50, 'min_samples_split': 260}      0.8513      0.0048       13
# {'min_samples_leaf': 50, 'min_samples_split': 280}      0.8516      0.0042       12
# {'min_samples_leaf': 50, 'min_samples_split': 300}      0.851      0.0032       20
# {'min_samples_leaf': 60, 'min_samples_split': 200}      0.8519      0.0046       7
# {'min_samples_leaf': 60, 'min_samples_split': 220}      0.8542      0.0039       1
# {'min_samples_leaf': 60, 'min_samples_split': 240}      0.8513      0.0039       13
# {'min_samples_leaf': 60, 'min_samples_split': 260}      0.8495      0.0051       34
# {'min_samples_leaf': 60, 'min_samples_split': 280}      0.851      0.0031       21
# {'min_samples_leaf': 60, 'min_samples_split': 300}      0.8498      0.006       32
# {'min_samples_leaf': 70, 'min_samples_split': 200}      0.8504      0.0072       26
# {'min_samples_leaf': 70, 'min_samples_split': 220}      0.8528      0.0053       2
# {'min_samples_leaf': 70, 'min_samples_split': 240}      0.8522      0.0029       5
# {'min_samples_leaf': 70, 'min_samples_split': 260}      0.8525      0.0024       3
# {'min_samples_leaf': 70, 'min_samples_split': 280}      0.8519      0.0019       10
# {'min_samples_leaf': 70, 'min_samples_split': 300}      0.851      0.0033       22
# {'min_samples_leaf': 80, 'min_samples_split': 200}      0.8516      0.0048       11
# {'min_samples_leaf': 80, 'min_samples_split': 220}      0.8513      0.0038       13
# {'min_samples_leaf': 80, 'min_samples_split': 240}      0.8507      0.0036       25
# {'min_samples_leaf': 80, 'min_samples_split': 260}      0.8495      0.0044       37
# {'min_samples_leaf': 80, 'min_samples_split': 280}      0.8495      0.003       40
# {'min_samples_leaf': 80, 'min_samples_split': 300}      0.8501      0.0042       30

# %%
gridSearch3.best_params_, gridSearch3.best_score_
# Out:
# ({'min_samples_leaf': 60, 'min_samples_split': 220}, 0.8542363280654282)

# %%
gridSearch3.best_estimator_.fit(x,y)
# Out:
# GradientBoostingClassifier(max_depth=5, max_features='sqrt',
#                            min_samples_leaf=60, min_samples_split=220,
#                            n_estimators=50, random_state=42, subsample=0.8)

# %%
gradBoost_importance=list(gridSearch3.best_estimator_.feature_importances_)
allfeatures=data.drop('TenYearCHD',axis=1)
features=list(allfeatures.columns)
fig = plt.figure(figsize = (15, 5)) 
plt.barh(features, gradBoost_importance, color ='blue') 
plt.title('Gradient Boosting Classifier model(Grid Search3)-Feature importances')
plt.xlabel("Features/Factors causing heart disease") 
plt.ylabel("Feature importance") 
plt.show()

# %%
zipped_lists=zip(gradBoost_importance,features)
zipped_lists=list(sorted(zipped_lists))
importanceSorted,featuresSorted = zip(*zipped_lists)
fig = plt.figure(figsize = (20, 5)) 
plt.barh(list(featuresSorted), list(importanceSorted), color ='blue') 
plt.title('Gradient Boosting Classifier model(Final Model Sorted)-Feature importances')
plt.xlabel("Features/Factors causing heart disease") 
plt.ylabel("Feature importance") 
plt.show()

# %% [markdown]
# Parameters fixed till now:
#
# n_estimators-50, max_depth-5, min_samples_split-220, min_samples_leaf-60

# %%
param_grid4 = {'max_features':range(2,9)}
gridSearch4=GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, n_estimators=50, max_depth=5, min_samples_split=220, min_samples_leaf=60, subsample=0.8, random_state=42), 
param_grid = param_grid4, scoring='f1_micro', cv=5)
gridSearch4.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=GradientBoostingClassifier(max_depth=5,
#                                                   min_samples_leaf=60,
#                                                   min_samples_split=220,
#                                                   n_estimators=50,
#                                                   random_state=42,
#                                                   subsample=0.8),
#              param_grid={'max_features': range(2, 9)}, scoring='f1_micro')

# %%
results=gridSearch4.cv_results_
print("           Params       MeanTestScore    StdTestScore   Rank")
for i in range(len(results['params'])):
  print(results['params'][i],'    ',round(results['mean_test_score'][i],4),'    ',round(results['std_test_score'][i],4),'     ',results['rank_test_score'][i])
# Out:
#            Params       MeanTestScore    StdTestScore   Rank
# {'max_features': 2}      0.8513      0.0052       4
# {'max_features': 3}      0.8542      0.0039       1
# {'max_features': 4}      0.8516      0.0066       3
# {'max_features': 5}      0.8489      0.0065       6
# {'max_features': 6}      0.8519      0.0038       2
# {'max_features': 7}      0.8486      0.0066       7
# {'max_features': 8}      0.8507      0.0055       5

# %%
gridSearch4.best_params_, gridSearch4.best_score_
# Out:
# ({'max_features': 3}, 0.8542363280654282)

# %%
models.append("Gradient Boosting Classifier - After hyper parameter tuning")
f1Scores.append(0.8542363280654282)

# %%
gridSearch4.best_estimator_
# Out:
# GradientBoostingClassifier(max_depth=5, max_features=3, min_samples_leaf=60,
#                            min_samples_split=220, n_estimators=50,
#                            random_state=42, subsample=0.8)

# %%
finalModel=GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
                           learning_rate=0.1, loss='deviance', max_depth=5,
                           max_features=3, max_leaf_nodes=None,
                           min_impurity_decrease=0.0,
                           min_samples_leaf=60, min_samples_split=220,
                           min_weight_fraction_leaf=0.0, n_estimators=50,
                           n_iter_no_change=None,
                           random_state=42, subsample=0.8, tol=0.0001,
                           validation_fraction=0.1, verbose=0,
                           warm_start=False)
finalModel.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(max_depth=5, max_features=3, min_samples_leaf=60,
#                            min_samples_split=220, n_estimators=50,
#                            random_state=42, subsample=0.8)

# %%
finalModel.score(x_test,y_test)
# Out:
# 0.8431603773584906

# %%
scores_finalModel=cross_val_score(finalModel,x,y,cv=10,scoring="f1_micro")
print(scores_finalModel)
print(scores_finalModel.mean())
# Out:
# [0.83726415 0.85141509 0.85613208 0.85377358 0.8490566  0.8490566
#  0.8490566  0.8534279  0.85106383 0.85106383]
# 0.8501310272536688

# %%
gradBoost_importance=list(finalModel.feature_importances_)
allfeatures=data.drop('TenYearCHD',axis=1)
features=list(allfeatures.columns)
fig = plt.figure(figsize = (20, 5)) 
plt.barh(features, gradBoost_importance, color ='blue') 
plt.title('Gradient Boosting Classifier model(Final Model)-Feature importances')
plt.xlabel("Features/Factors causing heart disease") 
plt.ylabel("Feature importance") 
plt.show()

# %%
zipped_lists=zip(gradBoost_importance,features)
zipped_lists=list(sorted(zipped_lists))
importanceSorted,featuresSorted = zip(*zipped_lists)
fig = plt.figure(figsize = (20, 5)) 
plt.barh(list(featuresSorted), list(importanceSorted), color ='blue') 
plt.title('Gradient Boosting Classifier model(Final Model Sorted)-Feature importances')
plt.ylabel("Features/Factors causing heart disease") 
plt.xlabel("Feature importance") 
plt.show()

# %%
import pickle

# %%
pickle.dump(finalModel,open('TenYearCHDPrediction.pkl','wb'))

# %%
myModel=pickle.load(open('TenYearCHDPrediction.pkl','rb'))

# %%
features
# Out:
# ['male',
#  'age',
#  'education',
#  'currentSmoker',
#  'cigsPerDay',
#  'BPMeds',
#  'prevalentStroke',
#  'prevalentHyp',
#  'diabetes',
#  'totChol',
#  'sysBP',
#  'diaBP',
#  'BMI',
#  'heartRate',
#  'glucose']

# %%
myModel.predict([[0,20,3,0,0,0,0,0,0,160,95,65,23.5,75,75]])
# Out:
# array([0])

# %%
myModel.predict([[1,59,2,1,2,0,0,1,0,190,120,110,25.4,85,80]])
# Out:
# array([1])

# %%
models, f1Scores
# Out:
# (['Logitic Regression',
#   'Decision Tree',
#   'Decision Tree 2',
#   'SVM 1',
#   'SVM 2',
#   'Random Forest',
#   'Gradient Boosting Classifier',
#   'XG Boost Classifier',
#   'Stacking Classifier',
#   'Gradient Boosting Classifier - After hyper parameter tuning'],
#  [0.8550855301306927,
#   0.7467521967973594,
#   0.7984471876533299,
#   0.8430471921138321,
#   0.84800671305589,
#   0.8491876310272536,
#   0.8482420045497123,
#   0.8482420045497123,
#   0.8466981132075472,
#   0.8542363280654282])

# %%
zipped_lists=zip(f1Scores, models)
zipped_lists=list(sorted(zipped_lists))
f1ScoresSorted,modelsSorted = zip(*zipped_lists)
fig = plt.figure(figsize = (20, 5)) 
plt.barh(list(modelsSorted), list(f1ScoresSorted), color ='cyan') 
plt.title('Models and their performance')
plt.xlabel("F1 Score of classifiers") 
plt.ylabel("Models/Classifiers") 
plt.show()

# %% [markdown]
# EDA

# %%
data.head()
# Out:
#    male  age  education  currentSmoker  ...    BMI  heartRate  glucose  TenYearCHD
# 0     1   39        4.0              0  ...  26.97       80.0     77.0           0
# 1     0   46        2.0              0  ...  28.73       95.0     76.0           0
# 2     1   48        1.0              1  ...  25.34       75.0     70.0           0
# 3     0   61        3.0              1  ...  28.58       65.0    103.0           1
# 4     0   46        3.0              1  ...  23.10       85.0     85.0           0
#
# [5 rows x 16 columns]

# %%
sns.relplot('totChol','heartRate',data=data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot('totChol','heartRate',data=data,hue="TenYearCHD")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot('totChol','heartRate',data=data,hue="TenYearCHD",style="currentSmoker")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot('totChol','heartRate',data=data,col="TenYearCHD",hue="prevalentHyp")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot('totChol','heartRate',data=data,size="age",sizes=(20,170))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot('totChol','heartRate',data=data,size="cigsPerDay",sizes=(20,170))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot('totChol','heartRate',data=data,size="cigsPerDay",sizes=(20,170),col="TenYearCHD",row="prevalentHyp")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot('sysBP','glucose',data=data,hue="male",col="prevalentHyp",row="currentSmoker")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot('sysBP','totChol',data=data,hue="male",col="currentSmoker")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot('sysBP','totChol',data=data,hue="prevalentHyp")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot('sysBP','totChol',data=data,col="currentSmoker",hue="male")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot('age','TenYearCHD',data=data,kind='line')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot('age','TenYearCHD',data=data,kind='line',hue='prevalentHyp')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot('BMI','sysBP',data=data.query("BMI<40"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot('TenYearCHD','age',data=data,kind='violin')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot('TenYearCHD','age',data=data,kind='violin',hue="prevalentHyp")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data_numerical=pd.concat([data_numerical,data.TenYearCHD],axis=1)
sns.pairplot(data_numerical,hue="TenYearCHD")

# %%
sns.catplot('TenYearCHD','cigsPerDay',kind='violin',data=data,hue="prevalentHyp")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
